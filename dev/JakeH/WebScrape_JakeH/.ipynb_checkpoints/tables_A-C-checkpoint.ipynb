# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
base_url = 'https://www.en.wikipedia.org'

url = 'https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(0%E2%80%939,_A%E2%80%93C)'
page = requests.get(url)
soup = BeautifulSoup(page.text, "lxml")

# %%
my_tables = soup.find_all('table',{'class':'wikitable'})

# %%
book_titles = []
movie_titles = []

for table in my_tables:
    rows = table.find_all('tr')
    
    for row in rows:
        cells = row.find_all('td')
        
        
        if len(cells) > 1:
            book_title = cells[0]
            book_titles.append(book_title.text.strip())
            
            movie_title = cells[1]
            movie_titles.append(movie_title.text.strip())

# %%
df1 = pd.DataFrame({'Book Titles': book_titles,
                    'Movie Titles': movie_titles})
df1
# Out:
#                                            Book Titles  \
# 0           The A.B.C. Murders (1936), Agatha Christie
# 1              À ton image (1998), Louise L. Lambrichs
# 2       De Aanslag (The Assault) (1982), Harry Mulisch
# 3                      About a Boy (1998), Nick Hornby
# 4                   About Schmidt (1996), Louis Begley
# 5                Absolute Power (1996), David Baldacci
# 6            The Accidental Tourist (1985), Anne Tyler
# 7                    Across 110th (1970), Wally Ferris
# 8    Adam Resurrected (Man, Son of a Dog) (1971), Y...
# 9                      Adams Fall (2000), Sean Desmond
# 10                  Addie Pray (1971), Joe David Brown
# 11            Adiliya by the River (1999), Jin Renshun
# 12                   Adolphe (1816), Benjamin Constant
# 13                       Adventure (1911), Jack London
# 14              The Adventurers (1966), Harold Robbins
# 15   The Adventures of Captain Alatriste (Las avent...
# 16   The Adventures of Hajji Baba of Ispahan (1824)...
# 17   Adventures of Huckleberry Finn (1884), Mark Twain
# 18   The Adventures of Pinocchio (1883), Carlo Collodi
# 19   The Adventures of Sherlock Holmes (1891–1892) ...
# 20     The Adventures of Tom Sawyer (1876), Mark Twain
# 21              Advise and Consent (1959), Allen Drury
# 22   Aelita (1923) (a. k. a. Aelita or, The Decline...
# 23            The African Queen (1935), C. S. Forester
# 24           After Dark, My Sweet (1955), Jim Thompson
# 25                    After Hours (1979), Edwin Torres
# 26           After the Funeral (1953), Agatha Christie
# 27          The Age of Innocence (1921), Edith Wharton
# 28      The Agony and the Ecstasy (1961), Irving Stone
# 29   Äideistä parhain (Mother of Mine) (1999), Heik...
# ..                                                 ...
# 392                  Comrade Jacob (1961), David Caute
# 393                 Comrades (1909), Thomas Dixon, Jr.
# 394        The Constant Nymph (1923), Margaret Kennedy
# 395                 Cool Hand Luke (1965), Donn Pearce
# 396  Le comte de Monte Cristo (The Count of Monte C...
# 397                The Comedians (1966), Graham Greene
# 398  [[Louis L'Amour#Novels - Conagher (1968) ISBN ...
# 399  La comtesse de Cagliostro (1924), Maurice Leblanc
# 400  Confessions of a Crap Artist (1975), Philip K....
# 401                     Congo (1980), Michael Crichton
# 402  A Connecticut Yankee in King Arthur's Court (1...
# 403        The Constant Gardener (2001), John le Carré
# 404                         Contact (1985), Carl Sagan
# 405                 Cool Hand Luke (1965), Donn Pearce
# 406        Cops and Robbers (1972), Donald E. Westlake
# 407  Corazón salvaje (Wild Heart) (1957), Caridad B...
# 408                   Coroner Creek (1945), Luke Short
# 409          The Cowboys (1971), William Dale Jennings
# 410                Cracking India (1991), Bapsi Sidhwa
# 411                        Crash (1973), J. G. Ballard
# 412                       Creator (1980), Jeremy Leven
# 413  O Crime do Padre Amaro (The Crime of Father Am...
# 414  [[Louis L'Amour#Novels - Crossfire Trail (1954...
# 415   Crouching Tiger, Hidden Dragon (1942), Wang Dulu
# 416           The Cruel Sea (1951), Nicholas Monsarrat
# 417  Cry Wolf (a. k. a. The Demarest Inheritance) (...
# 418           Cutter and Bone (1976), Newton Thornburg
# 419                       Cyborg (1972), Martin Caidin
# 420         Cycle of the Werewolf (1983), Stephen King
# 421  The Cypher (a. k. a. The Cipher) (1961), Gordo...
#
#                                           Movie Titles
# 0    The Alphabet Murders (1966)The A.B.C. Murders ...
# 1                                   À ton image (2004)
# 2                                   The Assault (1986)
# 3                                   About a Boy (2002)
# 4                                 About Schmidt (2002)
# 5                                Absolute Power (1997)
# 6                        The Accidental Tourist (1988)
# 7                           Across 110th Street (1972)
# 8                              Adam Resurrected (2009)
# 9                                       Abandon (2002)
# 10                                   Paper Moon (1973)
# 11                                    Green Tea (2003)
# 12                                      Adolphe (2002)
# 13                                    Adventure (1925)
# 14                              The Adventurers (1970)
# 15                                    Alatriste (2006)
# 16                 The Adventures of Hajji Baba (1954)
# 17   Huck and Tom (1918)Huckleberry Finn (1920)Huck...
# 18   The Adventures of Pinocchio (1936) (Unfinished...
# 19   Adventures of Sherlock Holmes; or, Held for Ra...
# 20   Tom Sawyer (1907)Tom Sawyer (1917)* Huck and T...
# 21                             Advise & Consent (1962)
# 22                                       Aelita (1924)
# 23                            The African Queen (1951)
# 24                         After Dark, My Sweet (1990)
# 25                                Carlito's Way (1993)
# 26                         Murder at the Gallop (1963)
# 27   The Age of Innocence (1924)The Age of Innocenc...
# 28                    The Agony and the Ecstasy (1965)
# 29   Äideistä parhain (Mother of Mine) (2005) (a. k...
# ..                                                 ...
# 392                                  Winstanley (1975)
# 393                         Bolshevism on Trial (1919)
# 394  The Constant Nymph (1928)The Constant Nymph (1...
# 395                              Cool Hand Luke (1967)
# 396  The Count of Monte Cristo (1908)The Count of M...
# 397                               The Comedians (1967)
# 398                               Conagher (1991) (TV)
# 399                                Arsène Lupin (2004)
# 400  Confessions d'un Barjo (Confessions of a Barjo...
# 401                                       Congo (1995)
# 402  A Connecticut Yankee in King Arthur's Court (1...
# 403                       The Constant Gardener (2005)
# 404                                     Contact (1997)
# 405                              Cool Hand Luke (1967)
# 406                            Cops and Robbers (1973)
# 407  Corazón salvaje (1956)Juan del Diablo (1960)Co...
# 408                               Coroner Creek (1948)
# 409                                 The Cowboys (1972)
# 410                                       Earth (1998)
# 411                                       Crash (1996)
# 412                                     Creator (1985)
# 413  El crimen del Padre Amaro (The Crime of Father...
# 414                        Crossfire Trail (2001) (TV)
# 415              Crouching Tiger, Hidden Dragon (2000)
# 416                               The Cruel Sea (1953)
# 417                                    Cry Wolf (1947)
# 418                                Cutter's Way (1981)
# 419             The Six Million Dollar Man (1973) (TV)
# 420                               Silver Bullet (1985)
# 421                                   Arabesque (1966)
#
# [422 rows x 2 columns]

# %%
df1.to_csv('titles_a_c', sep=',', encoding='utf-8', index=False)
